# %%
# !pip install mysql-connector-python

# %%
import  mysql.connector as connection
conn=connection.connect(host='localhost',user='root',password='mysql')
cur=conn.cursor()
query="show databases"
res=cur.execute(query)
data=cur.fetchall()

# %%
data
# Out:
# [('finanace',),
#  ('gopi011',),
#  ('gopi0112',),
#  ('gopi1234',),
#  ('gopi12345',),
#  ('gopi2',),
#  ('information_schema',),
#  ('mysql',),
#  ('mysqldatabase',),
#  ('mysqldatabase07',),
#  ('mysqldatabase1',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
len(data)
# Out:
# 15

# %%
for i in range(1,len(data)):
        print(data[i][0])
# Out:
# gopi011
# gopi0112
# gopi1234
# gopi12345
# gopi2
# information_schema
# mysql
# mysqldatabase
# mysqldatabase07
# mysqldatabase1
# performance_schema
# sakila
# sys
# world

# %%
data[1][0]
# Out:
# 'gopi011'

# %%
cur.execute("create database mysqldatabase07")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'mysqldatabase07'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 cur.execute("create database mysqldatabase07")
#
# ...

# %%
cur.execute("create database gopi0112")

# %%
for i in range(1,len(data)):
        print(data[i][0])
dict={}
#dictionary format
for i in range(len(data)):
    dict[i]=data[i][0]
dict
# Out:
# gopi011
# gopi0112
# gopi1234
# gopi12345
# gopi2
# information_schema
# mysql
# mysqldatabase
# mysqldatabase07
# mysqldatabase1
# performance_schema
# sakila
# sys
# world
# {0: 'finanace',
#  1: 'gopi011',
#  2: 'gopi0112',
#  3: 'gopi1234',
#  4: 'gopi12345',
#  5: 'gopi2',
#  6: 'information_schema',
#  7: 'mysql',
#  8: 'mysqldatabase',
#  9: 'mysqldatabase07',
#  10: 'mysqldatabase1',
#  11: 'performance_schema',
#  12: 'sakila',
#  13: 'sys',
#  14: 'world'}

# %%
conn.close()

# %% [markdown]
# # CREATING A TABLE WRT TO DATABASE

# %%
mydb=connection.connect(host='localhost',database='gopi0112',user='root',password='mysql',use_pure=True)

# %%
mydb.is_connected()
# Out:
# True

# %%
cur=mydb.cursor()
cur.execute("create table test0(x1 INt(5),x2 VARCHAR(20),x3 DATE)")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[101], line 2
#       1 cur=mydb.cursor()
# ----> 2 cur.execute("create table test0(x1 INt(5),x2 VARCHAR(20),x3 DATE)")
#
# File ~\anaconda3\lib\site-packages\mysql\connector\cursor.py:615, in MySQLCursor.execute(self, operation, params, multi)
#     612     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     614 try:
# --> 615     self._handle_result(self._connection.cmd_query(stmt))
#     616 except InterfaceError as err:
#     617     if self._connection.have_next_result:
#
# File ~\anaconda3\lib\site-packages\mysql\connector\connection.py:1046, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#    1044 query = bytes(packet)
#    1045 try:
# -> 1046     result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#    1047 except ProgrammingError as err:
# ...

# %%
query="insert into test0 values (208244234,'gopi','2002-07-08')"
query="insert into test0 values (208244234,'gopi','2002-07-08')"
query="insert into test0 values (208244234,'gopi','2002-07-08')"
query="insert into test0 values (208244234,'gopi','2002-07-08')"


cur.execute(query)
mydb.commit()

# %%
cur1=mydb.cursor()

# %%
cur1.execute("select * from test0")

# %%
revive=cur1.fetchall()

# %%
revive
# Out:
# [(20834, 'gopi', datetime.date(2002, 7, 8)),
#  (20834, 'gopi', datetime.date(2002, 7, 8)),
#  (20834, 'gopi', datetime.date(2002, 7, 8)),
#  (20834, 'gopi', datetime.date(2002, 7, 8)),
#  (20834, 'gopi', datetime.date(2002, 7, 8)),
#  (208252, 'gopi', datetime.date(2002, 7, 8)),
#  (208252, 'gopi', datetime.date(2002, 7, 8)),
#  (208244, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
#  (208244234, 'gopi', datetime.date(2002, 7, 8)),
# ...

# %%
for i in range(len(revive)):
    print(revive[i])
# Out:
# (20834, 'gopi', datetime.date(2002, 7, 8))
# (20834, 'gopi', datetime.date(2002, 7, 8))
# (20834, 'gopi', datetime.date(2002, 7, 8))
# (20834, 'gopi', datetime.date(2002, 7, 8))
# (20834, 'gopi', datetime.date(2002, 7, 8))
# (208252, 'gopi', datetime.date(2002, 7, 8))
# (208252, 'gopi', datetime.date(2002, 7, 8))
# (208244, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# (208244234, 'gopi', datetime.date(2002, 7, 8))
# ...

# %%
cur1=mydb.cursor()

# %%
 cur.execute("select x1,x2 from test0")
for i in cur.fetchall():
    print(i)
# Out:
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (208252, 'gopi')
# (208252, 'gopi')
# (208244, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (2875, 'vennela')
# (2875, 'vennela')
# (2875, 'vennela')
# (2875, 'saala')
# (2875, 'cup')
# (2875, 'kohli')
# (2875, 'kohli')
# (2875, 'viraaat')
# (2875, 'namde')
# (208244234, 'gopi')

# %% [markdown]
# # fetching data and storing in data frame format

# %%
import pandas as pd
mydb=connection.connect(host='localhost',database='gopi0112',user='root',password='mysql',use_pure=True)

# %%
cur1=mydb.cursor()

# %%
query="select x1,x2 from test0"
sql_df=pd.read_sql("select * from test0",mydb)
# Out:
# C:\Users\gopi goud\AppData\Local\Temp\ipykernel_11756\3907295156.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_df=pd.read_sql("select * from test0",mydb)

# %%
sql_df
# Out:
#            x1       x2          x3
# 0       20834     gopi  2002-07-08
# 1       20834     gopi  2002-07-08
# 2       20834     gopi  2002-07-08
# 3       20834     gopi  2002-07-08
# 4       20834     gopi  2002-07-08
# 5      208252     gopi  2002-07-08
# 6      208252     gopi  2002-07-08
# 7      208244     gopi  2002-07-08
# 8   208244234     gopi  2002-07-08
# 9   208244234     gopi  2002-07-08
# 10  208244234     gopi  2002-07-08
# 11  208244234     gopi  2002-07-08
# 12  208244234     gopi  2002-07-08
# 13  208244234     gopi  2002-07-08
# 14  208244234     gopi  2002-07-08
# 15  208244234     gopi  2002-07-08
# 16  208244234     gopi  2002-07-08
# 17  208244234     gopi  2002-07-08
# 18  208244234     gopi  2002-07-08
# 19  208244234     gopi  2002-07-08
# 20  208244234     gopi  2002-07-08
# 21  208244234     gopi  2002-07-08
# 22  208244234     gopi  2002-07-08
# 23  208244234     gopi  2002-07-08
# 24  208244234     gopi  2002-07-08
# 25       2875  vennela  2005-06-08
# ...

# %%
acce_data=pd.read_sql(query,mydb)
# Out:
# C:\Users\gopi goud\AppData\Local\Temp\ipykernel_11756\1419817383.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   acce_data=pd.read_sql(query,mydb)

# %%
acce_data
# Out:
#            x1       x2
# 0       20834     gopi
# 1       20834     gopi
# 2       20834     gopi
# 3       20834     gopi
# 4       20834     gopi
# 5      208252     gopi
# 6      208252     gopi
# 7      208244     gopi
# 8   208244234     gopi
# 9   208244234     gopi
# 10  208244234     gopi
# 11  208244234     gopi
# 12  208244234     gopi
# 13  208244234     gopi
# 14  208244234     gopi
# 15  208244234     gopi
# 16  208244234     gopi
# 17  208244234     gopi
# 18  208244234     gopi
# 19  208244234     gopi
# 20  208244234     gopi
# 21  208244234     gopi
# 22  208244234     gopi
# 23  208244234     gopi
# 24  208244234     gopi
# 25       2875  vennela
# 26       2875  vennela
# 27       2875  vennela
# 28       2875    saala
# 29       2875      cup
# 30       2875    kohli
# 31       2875    kohli
# 32       2875  viraaat
# 33       2875    namde
# 34  208244234     gopi

# %%
sql_df.to_sql
# Out:
# <bound method NDFrame.to_sql of            x1       x2          x3
# 0       20834     gopi  2002-07-08
# 1       20834     gopi  2002-07-08
# 2       20834     gopi  2002-07-08
# 3       20834     gopi  2002-07-08
# 4       20834     gopi  2002-07-08
# 5      208252     gopi  2002-07-08
# 6      208252     gopi  2002-07-08
# 7      208244     gopi  2002-07-08
# 8   208244234     gopi  2002-07-08
# 9   208244234     gopi  2002-07-08
# 10  208244234     gopi  2002-07-08
# 11  208244234     gopi  2002-07-08
# 12  208244234     gopi  2002-07-08
# 13  208244234     gopi  2002-07-08
# 14  208244234     gopi  2002-07-08
# 15  208244234     gopi  2002-07-08
# 16  208244234     gopi  2002-07-08
# 17  208244234     gopi  2002-07-08
# 18  208244234     gopi  2002-07-08
# 19  208244234     gopi  2002-07-08
# 20  208244234     gopi  2002-07-08
# 21  208244234     gopi  2002-07-08
# 22  208244234     gopi  2002-07-08
# 23  208244234     gopi  2002-07-08
# 24  208244234     gopi  2002-07-08
# ...

# %%
sql_df.to_csv('mysqldata.csv')

# %%
import pandas as pd
import mysql.connector as connection

# %%
import pandas as pd
mydb=connection.connect(host='localhost',database='gopi0112',user='root',password='mysql',use_pure=True)
cur=mydb.cursor()

# %%
mydb.is_connected()
# Out:
# True

# %%
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
cur.execute("insert into test0 values (2875,'namde','2005-06-08')")
query="select x1,x2 from test0"


cur.execute(query)

# %%
result11=cur.fetchall()

# %%
result11
# Out:
# [(20834, 'gopi'),
#  (20834, 'gopi'),
#  (20834, 'gopi'),
#  (20834, 'gopi'),
#  (20834, 'gopi'),
#  (208252, 'gopi'),
#  (208252, 'gopi'),
#  (208244, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (208244234, 'gopi'),
#  (2875, 'vennela'),
#  (2875, 'vennela'),
#  (2875, 'vennela'),
#  (2875, 'saala'),
#  (2875, 'cup'),
#  (2875, 'kohli'),
#  (2875, 'kohli'),
#  (2875, 'viraaat'),
#  (2875, 'namde'),
#  (208244234, 'gopi'),
#  (2875, 'ganed'),
#  (2875, 'kohli'),
#  (2876, 'kohli'),
#  (2875, 'namde'),
#  (2875, 'namde'),
#  (2875, 'namde'),
#  (2875, 'namde'),
#  (2875, 'namde'),
#  (2875, 'namde'),
#  (2875, 'namde'),
# ...

# %%
for i in range(len(result11)):
    print(result11[i])
# Out:
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (20834, 'gopi')
# (208252, 'gopi')
# (208252, 'gopi')
# (208244, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (208244234, 'gopi')
# (2875, 'vennela')
# (2875, 'vennela')
# (2875, 'vennela')
# (2875, 'saala')
# (2875, 'cup')
# (2875, 'kohli')
# (2875, 'kohli')
# (2875, 'viraaat')
# (2875, 'namde')
# (208244234, 'gopi')
# (2875, 'ganed')
# (2875, 'kohli')
# (2876, 'kohli')
# (2875, 'namde')
# (2875, 'namde')
# (2875, 'namde')
# (2875, 'namde')
# (2875, 'namde')
# (2875, 'namde')
# (2875, 'namde')

# %%
query2="select * from test0 where x2='saala'"

# %%
cur.execute(query2)

# %%
res1=cur.fetchall()

# %%
res1
# Out:
# [(2875, 'saala', datetime.date(2005, 6, 8))]

# %%
query3="select * from test0 where x2='kohli'"

# %%
cur.execute(query3)

# %%
cur.fetchall()
# Out:
# [(2875, 'kohli', datetime.date(2005, 6, 8)),
#  (2875, 'kohli', datetime.date(2005, 6, 8)),
#  (2875, 'kohli', datetime.date(2005, 6, 8)),
#  (2876, 'kohli', datetime.date(2005, 6, 8))]

# %%
query4="select * from test0 where x1=2876"

# %%
cur.execute(query4)

# %%
cur.fetchall()
# Out:
# [(2876, 'kohli', datetime.date(2005, 6, 8))]

# %%
dta=pd.read_csv("wind-power-production-us.csv")

# %%
dta
# Out:
#          date  other_united_states  other_new_england  other_connecticut  \
# 0    Jan 2001                 6025                678                 75
# 1    Feb 2001                 5310                599                 77
# 2    Mar 2001                 5795                660                 96
# 3    Apr 2001                 5827                593                 92
# 4    May 2001                 5738                640                 72
# ..        ...                  ...                ...                ...
# 261  Oct 2022                50478                998                 89
# 262  Nov 2022                56144               1084                 83
# 263  Dec 2022                52394               1070                 78
# 264  Jan 2023                53152                983                 80
# 265  Feb 2023                56626                962                 75
#
#      other_maine  other_massachusetts  other_new_hampshire  \
# ...
